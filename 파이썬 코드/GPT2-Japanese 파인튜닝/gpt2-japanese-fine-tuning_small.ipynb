# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python --version
# Out:
# Python 3.8.16

# %%
# %cd /content/drive/MyDrive/Colab
# Out:
# /content/drive/MyDrive/Colab

# %%
# !git clone https://github.com/tanreinama/gpt2-japanese
# %cd gpt2-japanese
# !pip uninstall tensorflow -y
# !pip install -r requirements.txt
# Out:
# Cloning into 'gpt2-japanese'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 272 (delta 91), reused 81 (delta 80), pack-reused 165
# Receiving objects: 100% (272/272), 1.22 MiB | 10.77 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# /content/drive/MyDrive/Colab/gpt2-japanese
# Found existing installation: tensorflow 2.9.2
# Uninstalling tensorflow-2.9.2:
#   Successfully uninstalled tensorflow-2.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 588.3 MB 6.6 kB/s
# ...
#      |████████████████████████████████| 6.0 MB 39.0 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 55.6 MB/s
# ...
#      |████████████████████████████████| 439 kB 66.1 MB/s
# ...

# %%
# %cd gpt2-japanese
# !pip uninstall tensorflow -y
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/Colab/gpt2-japanese
# WARNING: Skipping tensorflow as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 588.3 MB 22 kB/s
# ...
#      |████████████████████████████████| 6.0 MB 56.7 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 63.1 MB/s
# ...
#      |████████████████████████████████| 439 kB 73.8 MB/s
# ...
#   Created wheel for jaconv: filename=jaconv-0.3-py3-none-any.whl size=15566 sha256=3efe3d636ed283bed455c1ebd29979ae84718ffacc8a2c1482115c0fd1cbf2ba
#   Stored in directory: /root/.cache/pip/wheels/73/e8/fb/b4ad8117719f79ac73bc05406d1768f845688cdbeed7aad87e
# Successfully built jaconv
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
# ...

# %%
# !wget https://www.nama.ne.jp/models/gpt2ja-small.tar.bz2
# !tar xvfj gpt2ja-small.tar.bz2
# Out:
# --2022-11-30 07:20:51--  https://www.nama.ne.jp/models/gpt2ja-small.tar.bz2
# Resolving www.nama.ne.jp (www.nama.ne.jp)... 112.78.112.176
# Connecting to www.nama.ne.jp (www.nama.ne.jp)|112.78.112.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386498483 (369M) [application/x-bzip2]
# Saving to: ‘gpt2ja-small.tar.bz2’
#
# gpt2ja-small.tar.bz 100%[===================>] 368.59M  3.39MB/s    in 1m 49s
#
# 2022-11-30 07:22:41 (3.37 MB/s) - ‘gpt2ja-small.tar.bz2’ saved [386498483/386498483]
#
# gpt2ja-small/
# gpt2ja-small/checkpoint
# gpt2ja-small/model-10412700.data-00000-of-00001
# gpt2ja-small/model-10412700.index
# gpt2ja-small/model-10412700.meta
# special_thanks.txt

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------
# absl-py                       1.3.0
# aeppl                         0.0.33
# aesara                        2.7.9
# aiohttp                       3.8.3
# aiosignal                     1.3.1
# alabaster                     0.7.12
# albumentations                1.2.1
# altair                        4.2.0
# appdirs                       1.4.4
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         22.1.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.11.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.1
# ...

# %%
# !python gpt2-generate.py --model gpt2ja-small --num_generate 1
# Out:
# 2022-12-06 04:59:01.888476: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-06 04:59:02.916424: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-06 04:59:02.916628: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# データセットの作成
# !git clone https://github.com/tanreinama/Japanese-BPEEncoder.git
# Out:
# Cloning into 'Japanese-BPEEncoder'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 37 (delta 16), reused 22 (delta 6), pack-reused 0
# Unpacking objects: 100% (37/37), done.

# %%
# !python ./Japanese-BPEEncoder/encode_bpe.py --src_dir corpus --dst_file finetune
# Out:
# append # corpus
# 100% 1/1 [00:04<00:00,  4.38s/it]

# %%
# !python run_finetune.py --base_model gpt2ja-small --dataset finetune.npz --run_name gpr2ja-finetune_run2-small
# Out:
# 2022-12-06 05:02:29.141281: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-06 05:02:30.054700: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-06 05:02:30.054828: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# ファインチューニングしたモデルの動作確認
# !python gpt2-generate.py --model checkpoint/gpr2ja-finetune_run2-small --context="見える" --num_generate 10
# Out:
# 2022-12-06 05:09:35.087747: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-06 05:09:35.987031: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-06 05:09:35.987143: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...
